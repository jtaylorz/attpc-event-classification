# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import sklearn.metrics
import numpy as np

import ast

# %%
results_path = '../keras-results/'

# %%
CNN_real2real_pC = open(results_path + 'CNN/real2real/pC.txt','r')
CNN_real2real_pC_contents = CNN_real2real_pC.read().split('\n')

CNN_real2real_pC_acc = ast.literal_eval(CNN_real2real_pC_contents[1])
CNN_real2real_pC_val_acc = ast.literal_eval(CNN_real2real_pC_contents[4])
CNN_real2real_pC_loss = ast.literal_eval(CNN_real2real_pC_contents[7])
CNN_real2real_pC_val_loss = ast.literal_eval(CNN_real2real_pC_contents[10])
print(CNN_real2real_pC_val_loss)
# Out:
# [6.283340182437365, 1.5135049223899841, 1.1797786666102619, 0.4308683235213101, 0.42203600275742104, 0.2992989845366117, 0.4467055723961606, 0.47670839928773295, 0.6686202150609982, 0.7320941344675315, 0.4287266292316149, 0.4761683214159007, 0.3907171390149223, 0.520971922953409, 0.6946448978199902, 0.7986961378014658, 0.5949719726772185, 0.66070925307449, 0.7241544914292728, 0.6308667674081853, 0.5855025416945081, 0.6953657056349682, 0.7260213138886256, 0.6217373084143338, 0.7916705010540457, 0.9825582787769279, 0.7963928831258855, 0.8085876505495424, 1.025299062249501, 0.9392696945237894, 1.5928207374663943, 0.8299515012918834, 0.7662317769553705, 0.8769235466050348, 1.0057954593483671, 0.8882199760593207, 0.979315896407099, 0.892980462400265, 1.0789304520269607, 1.03214119056268, 0.8979682850528998, 0.9949198079952206, 0.9756910562616369, 1.0752681582985006, 1.1836168312092779, 0.98166558036833, 1.083539263443628, 1.0685740938545594, 1.1445301037100983, 1.1879406915717865, 1.4664036484368137, 1.023332051078713, 1.1583779227337336, 1.1285331057527463, 1.2011821519775827, 1.257367844393686, 1.1185633961734662, 1.2221874406807247, 1.3904264599606027, 1.2469645359324857, 1.222630649121281, 1.1994358365056643, 1.8398070027284914, 1.1772551520782826, 1.1332710061819002, 1.3590944276580137, 1.1910763280768542, 1.2844234538693942, 1.2245907845363218, 1.2484305789979722, 1.1155699719055705, 1.2752249524971242, 1.208905871829878, 1.3239086059483927, 1.3315604717024987, 1.2161098083868935, 1.3144426351573493, 1.3534181926889248, 1.3364993371436997, 1.3340651028503847, 1.223147170555099, 1.3331533380157028, 1.190860766044816, 1.3588431949746484, 1.2288524298984336, 1.288333858572217, 1.3068993755199865, 1.3350585396431731, 1.648110113564643, 1.3204332980313627, 1.2547844758348103, 1.4029508306092, 1.2197744353221909, 1.194881687943538, 1.2461681800719757, 1.3216397598901302, 1.2044667779813303, 1.231137340703076, 1.3278398551425177, 1.258127254413276]

# %%
best_epoch = 6

fig, ax = plt.subplots(2, 2, squeeze=True, figsize=(18,12))
ax[0][0].plot(CNN_real2real_pC_acc)
ax[0][0].plot(CNN_real2real_pC_val_acc)
ax[0][0].set_title('CNN Accuracy - Tests with Real Data - Proton vs. Carbon')
ax[0][0].set_ylabel('Accuracy')
ax[0][0].set_xlabel('Epoch')
ax[0][0].legend(['Training Set', 'Test Set'], loc='lower right')
ax[0][0].set_ylim(-0.05, 1.05)
ax[0][0].plot(np.full((10,), best_epoch), np.linspace(-0.5, 1.5, 10), c='black')
ax[0][0].set_xticks([0, best_epoch, 20, 40, 60, 80, 100])
ax[0][0].set_xticklabels(['0', 'Optimal', '20', '40', '60', '80', '100'])

ax[0][1].plot(CNN_real2real_pC_loss)
ax[0][1].plot(CNN_real2real_pC_val_loss)
ax[0][1].set_title('CNN Cost - Tests with Real Data - Proton vs. Carbon')
ax[0][1].set_ylabel('Cost')
ax[0][1].set_xlabel('Epoch')
ax[0][1].legend(['Training Set', 'Test Set'], loc='upper right')
ax[0][1].set_ylim(-0.2, 7.0)
ax[0][1].plot(np.full((10,), best_epoch), np.linspace(-0.5, 7.0, 10), c='black')
ax[0][1].set_xticks([0, best_epoch, 20, 40, 60, 80, 100])
ax[0][1].set_xticklabels(['0', 'Optimal', '20', '40', '60', '80', '100'])

ax[1][0].plot(CNN_real2real_pC_acc[0:12])
ax[1][0].plot(CNN_real2real_pC_val_acc[0:12])
ax[1][0].set_title('CNN Accuracy - Optimal Training Period')
ax[1][0].set_ylabel('Accuracy')
ax[1][0].set_xlabel('Epoch')
ax[1][0].legend(['Training Set', 'Test Set'], loc='lower right')
ax[1][0].set_ylim(-0.05, 1.05)
ax[1][0].plot(np.full((10,), best_epoch), np.linspace(-0.5, 1.5, 10), c='black')
ax[1][0].set_xticks([0, 2, 4, 6, 8, 10])
ax[1][0].set_xticklabels(['0', '2', '4', 'Optimal', '8', '10'])


ax[1][1].plot(CNN_real2real_pC_loss[0:12])
ax[1][1].plot(CNN_real2real_pC_val_loss[0:12])
ax[1][1].set_title('CNN Cost - Optimal Training Period')
ax[1][1].set_ylabel('Cost')
ax[1][1].set_xlabel('Epoch')
ax[1][1].legend(['Training Set', 'Test Set'], loc='upper right')
ax[1][1].set_ylim(-0.2, 7.0)
ax[1][1].plot(np.full((10,), best_epoch), np.linspace(-0.5, 7.0, 10), c='black')
ax[1][1].set_xticks([0, 2, 4, 6, 8, 10])
ax[1][1].set_xticklabels(['0', '2', '4', 'Optimal', '8', '10'])

plt.savefig('../plots/results/thesis/NN-overfitting.pdf')
