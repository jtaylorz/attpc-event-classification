# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

import scipy as sp
import numpy as np
import pandas as pd

import pytpc
# Out:
# /usr/local/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# # Simulated Data

# %%
hdfpath = '../../data/tilt/p_40000_tilt_largeEvts.h5'
p_simfile = pytpc.HDFDataFile(hdfpath, 'r')

# %%
p_pt_counts = []
p_totalcharge = []

for evt in p_simfile:
    xyzs = evt.xyzs(peaks_only=True, drift_vel=5.2, clock=12.5, return_pads=False, baseline_correction=False, cg_times=False)
    pt_count = xyzs.shape[0]
    p_pt_counts.append(pt_count)
    p_totalcharge.append(sum(xyzs[:,3]))

# %%
print(sum(p_pt_counts)/len(p_pt_counts))
print(sum(p_totalcharge)/len(p_totalcharge))
# Out:
# 179.94662633434163
# 54133.96164095884

# %%
plt.hist(p_pt_counts, bins=100)
# Out:
# (array([2.732e+03, 2.838e+03, 3.190e+03, 3.268e+03, 3.173e+03, 2.490e+03,
#         1.993e+03, 1.895e+03, 1.697e+03, 1.434e+03, 1.343e+03, 1.174e+03,
#         1.028e+03, 1.114e+03, 9.760e+02, 7.780e+02, 8.550e+02, 7.550e+02,
#         5.940e+02, 6.220e+02, 5.280e+02, 4.380e+02, 4.420e+02, 3.920e+02,
#         2.950e+02, 3.340e+02, 2.850e+02, 2.630e+02, 2.150e+02, 1.990e+02,
#         1.530e+02, 1.440e+02, 1.620e+02, 1.330e+02, 1.380e+02, 1.450e+02,
#         1.200e+02, 1.060e+02, 1.210e+02, 9.000e+01, 9.900e+01, 9.000e+01,
#         7.100e+01, 6.900e+01, 6.100e+01, 5.800e+01, 7.800e+01, 6.200e+01,
#         5.800e+01, 5.000e+01, 5.100e+01, 4.900e+01, 4.600e+01, 3.900e+01,
#         3.000e+01, 4.000e+01, 2.400e+01, 2.700e+01, 2.500e+01, 3.200e+01,
#         2.400e+01, 1.900e+01, 1.800e+01, 2.300e+01, 2.000e+01, 1.100e+01,
#         1.500e+01, 1.500e+01, 1.300e+01, 8.000e+00, 1.500e+01, 6.000e+00,
#         1.100e+01, 7.000e+00, 1.400e+01, 5.000e+00, 8.000e+00, 6.000e+00,
# ...

# %%
plt.figure(figsize=(8,8))
p = plt.scatter(p_pt_counts, p_totalcharge, marker='o', c='black', alpha=0.6)
#C = plt.scatter(C_sim_count, C_sim_charge, marker='s', c='red', alpha=0.1)
#junk = plt.scatter(junk_sim_count, junk_sim_charge, marker='^', c='black', alpha=0.6)

plt.title("Simulated Proton Events")
plt.xlabel("Point Count")
plt.ylabel("Total Charge")
#plt.legend((p, C, junk), ('proton', 'carbon', 'junk'), loc='upper right')
#plt.legend((p, junk), ('proton', 'junk'), loc='upper right')

plt.ylim((0,3500000))
plt.xlim((0,1500))
# Out:
# (0, 1500)

# %%
hdfpath = '../../data/tilt/C_40000_tilt_largeEvts.h5'
C_simfile = pytpc.HDFDataFile(hdfpath, 'r')

# %%
C_pt_counts = []
C_totalcharge = []

for evt in C_simfile:
    xyzs = evt.xyzs(peaks_only=True, drift_vel=5.2, clock=12.5, return_pads=False, baseline_correction=False, cg_times=False)
    pt_count = xyzs.shape[0]
    C_pt_counts.append(pt_count)
    C_totalcharge.append(sum(xyzs[:,3]))

# %%
print(sum(C_pt_counts)/len(C_pt_counts))
print(sum(C_totalcharge)/len(C_totalcharge))
# Out:
# 118.3718407039824
# 332936.38107047346

# %%
plt.hist(C_pt_counts, bins=100)
# Out:
# (array([9.850e+02, 9.290e+02, 7.850e+02, 1.107e+03, 9.730e+02, 1.365e+03,
#         1.161e+03, 1.678e+03, 1.556e+03, 2.022e+03, 1.983e+03, 1.490e+03,
#         1.561e+03, 1.165e+03, 1.398e+03, 1.077e+03, 1.230e+03, 8.480e+02,
#         9.470e+02, 6.710e+02, 7.380e+02, 6.970e+02, 5.630e+02, 6.980e+02,
#         5.150e+02, 6.240e+02, 4.480e+02, 5.010e+02, 3.920e+02, 5.000e+02,
#         5.120e+02, 4.140e+02, 4.490e+02, 3.740e+02, 4.650e+02, 4.250e+02,
#         4.980e+02, 4.370e+02, 5.570e+02, 3.700e+02, 5.480e+02, 4.740e+02,
#         3.930e+02, 4.840e+02, 3.280e+02, 4.330e+02, 3.510e+02, 3.990e+02,
#         2.980e+02, 2.780e+02, 2.120e+02, 8.100e+01, 7.000e+01, 3.800e+01,
#         4.200e+01, 3.200e+01, 2.500e+01, 2.200e+01, 2.300e+01, 1.300e+01,
#         2.100e+01, 1.500e+01, 1.800e+01, 1.800e+01, 1.500e+01, 1.700e+01,
#         1.700e+01, 1.400e+01, 1.200e+01, 1.900e+01, 1.600e+01, 1.200e+01,
#         1.500e+01, 1.000e+01, 1.500e+01, 6.000e+00, 3.000e+00, 7.000e+00,
# ...

# %%
plt.figure(figsize=(8,8))
C = plt.scatter(C_pt_counts, C_totalcharge, marker='s', c='blue', alpha=0.1)

plt.title("Simulated Carbon Events")
plt.xlabel("Point Count")
plt.ylabel("Total Charge")

plt.ylim((0,3500000))
plt.xlim((0,1500))
# Out:
# (0, 1500)

# %% [markdown]
# # Real Data

# %%
data_path = '../../data/real/'
runs = ['0130', '0210']

# %%
p_real_ptcounts = []
p_real_totalcharge = []

C_real_ptcounts = []
C_real_totalcharge = []

junk_real_ptcounts = []
junk_real_totalcharge = []

# %%
for run in runs:
    data = pytpc.HDFDataFile(data_path + "run_" + run + ".h5", 'r')
    labels = pd.read_csv(data_path + "run_" + run + "_labels.csv", sep=',')
    print("Successfully loaded data and labels for run " + str(run) + ".")

    #discretize proton events
    p_indices = labels.loc[(labels['label'] == 'p')]['evt_id'].values

    for evt_id in p_indices:
        curEvt = data[evt_id]
        xyzs = curEvt.xyzs(peaks_only=True, drift_vel=5.2, clock=12.5, return_pads=False, baseline_correction=False, cg_times=False)
        pt_count = xyzs.shape[0]
        p_real_ptcounts.append(pt_count)
        p_real_totalcharge.append(sum(xyzs[:,3]))


    #discretize carbon eventsection=False, cg_times=False)
    C_indices = labels.loc[(labels['label'] == 'c')]['evt_id'].values

    for evt_id in C_indices:
        curEvt = data[evt_id]
        xyzs = curEvt.xyzs(peaks_only=True, drift_vel=5.2, clock=12.5, return_pads=False, baseline_correction=False, cg_times=False)
        pt_count = xyzs.shape[0]
        C_real_ptcounts.append(pt_count)
        C_real_totalcharge.append(sum(xyzs[:,3]))

    #discretize junk events
    junk_indices = labels.loc[(labels['label'] == 'j')]['evt_id'].values

    for evt_id in junk_indices:
        curEvt = data[evt_id]
        xyzs = curEvt.xyzs(peaks_only=True, drift_vel=5.2, clock=12.5, return_pads=False, baseline_correction=False, cg_times=False)
        pt_count = xyzs.shape[0]
        junk_real_ptcounts.append(pt_count)
        junk_real_totalcharge.append(sum(xyzs[:,3]))
# Out:
# Successfully loaded data and labels for run 0130.
# Successfully loaded data and labels for run 0210.

# %%
print(sum(p_real_ptcounts)/len(p_real_ptcounts))
print(sum(p_real_totalcharge)/len(p_real_totalcharge))
# Out:
# 432.01960784313724
# 203945.83680241293

# %%
print(sum(C_real_ptcounts)/len(C_real_ptcounts))
print(sum(C_real_totalcharge)/len(C_real_totalcharge))
# Out:
# 548.8588235294118
# 546772.9117647063

# %%
print(sum(junk_real_ptcounts)/len(junk_real_ptcounts))
print(sum(junk_real_totalcharge)/len(junk_real_totalcharge))
# Out:
# 410.7034400948992
# 192022.0122182679

# %%
plt.figure(figsize=(8,8))
p = plt.scatter(p_real_ptcounts, p_real_totalcharge, marker='o', c='black', alpha=0.6)

plt.title("Simulated Proton Events")
plt.xlabel("Point Count")
plt.ylabel("Total Charge")

plt.ylim((0,3500000))
plt.xlim((0,1500))
# Out:
# (0, 1500)

# %%
plt.figure(figsize=(8,8))
C = plt.scatter(C_real_ptcounts, C_real_totalcharge, marker='s', c='blue', alpha=0.6)

plt.title("Simulated Carbon Events")
plt.xlabel("Point Count")
plt.ylabel("Total Charge")

plt.ylim((0,3500000))
plt.xlim((0,1500))
# Out:
# (0, 1500)

# %%
font = {'family' : 'normal',
        'weight' : 'regular',
        'size'   : 14}

plt.rc('font', **font)

fig, ax = plt.subplots(2,2, figsize=(20,20))

ax[0][0].scatter(p_pt_counts, p_totalcharge, marker='o', c='black', alpha=0.6)
ax[0][0].set_title("Simulated Proton Events")
ax[0][0].set_xlabel("Point Count")
ax[0][0].set_ylabel("Total Charge")
ax[0][0].set_ylim((0,3500000))
ax[0][0].set_xlim((0,1500))

ax[0][1].scatter(C_pt_counts, C_totalcharge, marker='s', c='blue', alpha=0.6)
ax[0][1].set_title("Simulated Carbon Events")
ax[0][1].set_xlabel("Point Count")
ax[0][1].set_ylabel("Total Charge")
ax[0][1].set_ylim((0,3500000))
ax[0][1].set_xlim((0,1500))

ax[1][0].scatter(p_real_ptcounts, p_real_totalcharge, marker='o', c='black', alpha=0.6)
ax[1][0].set_title("Real Proton Events")
ax[1][0].set_xlabel("Point Count")
ax[1][0].set_ylabel("Total Charge")
ax[1][0].set_ylim((0,3500000))
ax[1][0].set_xlim((0,1500))

ax[1][1].scatter(C_real_ptcounts, C_real_totalcharge, marker='s', c='blue', alpha=0.6)
ax[1][1].set_title("Real Carbon Events")
ax[1][1].set_xlabel("Point Count")
ax[1][1].set_ylabel("Total Charge")
ax[1][1].set_ylim((0,3500000))
ax[1][1].set_xlim((0,1500))

#plt.savefig('../../plots/results/thesis/point-charge-plots.pdf')
# Out:
# (0, 1500)
# /usr/local/lib/python3.6/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
